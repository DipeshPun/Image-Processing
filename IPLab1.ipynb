# %% [markdown]
# <a href="https://colab.research.google.com/github/DipeshPun/Image-Processing/blob/main/IPLab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
#read images
img1= cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/everest.jpg",0)
img1=cv2.resize(img1,(300,300))
print(img1)
print(img1.shape)
# Out:
# [[109 110 110 ... 112 112 112]
#  [110 110 111 ... 113 110 112]
#  [111 109 112 ... 112 110 113]
#  ...
#  [ 81  57  57 ...  21  21  23]
#  [111  62 113 ...  21  23  18]
#  [ 83  56  63 ...  21  22  21]]
# (300, 300)

# %%
plt.imshow(img1,cmap='gray')
plt.title("Everest")
plt.show()

# %%
img2= cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/flag.jpg",0)
img2=cv2.resize(img2,(300,300))
print(img2)
print(img2.shape)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# (300, 300)

# %%
plt.imshow(img2,cmap='gray')
plt.title("Flag")
plt.show()

# %%
#Adding two images together
img3 = cv2.addWeighted(img1, 0.3, img2, 0.7, 0)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.title("Addition")
plt.imshow(img3, cmap='gray')
plt.show()

# %%
#Adding two images to form new image
import numpy as np

img1 = np.array([[100, 200, 123],
              [45, 145, 166]])
img2 = np.array([[136, 133, 155],
              [126, 147, 188]])

img3 = np.empty(img1.shape)

for i in range(img1.shape[0]):
  for j in range(img1.shape[1]):
    img3[i, j] = img1[i, j]*0.3 + img2[i, j]*0.7

print(img3)
# Out:
# [[125.2 153.1 145.4]
#  [101.7 146.4 181.4]]

# %%
#Subtracting same image
img4=cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/everest.jpg")
img5=cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/everest.jpg")
img6=cv2.subtract(img4,img5)
plt.title("Subtraction")
plt.imshow(img6, cmap='gray')
plt.show()

# %%
#Image 1
img1=cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/petal.jpg")
plt.imshow(img1)
plt.show()

# %%
#Image 2
img2=cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/purple.jpg")
plt.imshow(img2)
plt.show()

# %%
#Subtracting two different images
img1 = cv2.resize(img1, (250, 250))#Resize images to a common size
img2 = cv2.resize(img2, (250, 250))
img3=img1 - img2
plt.title("Subtraction")
plt.imshow(img3)
plt.show()

# %%
imgone =  cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/everest.jpg")
imgone = cv2.resize(imgone, (250, 250))
imgthree = np.empty((250, 250, 3), dtype=np.uint8)
for i in range(0, 250):
    for j in range(0, 250):
        imgthree[i][j] = np.clip(imgone[i][j] *1.5, 0, 255)
plt.imshow(cv2.cvtColor(imgthree, cv2.COLOR_BGR2RGB))

# %%
output_path='/content/drive/MyDrive/images-20250302T053354Z-001/images/updagedeverst.jpg'
cv2.imwrite(output_path, imgthree)
# Out:
# True

# %%
show_image=cv2.imread(output_path)
plt.imshow(cv2.cvtColor(show_image,cv2.COLOR_BGR2RGB))

# %%
img1=cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/test.png",cv2.COLOR_BGR2RGB)
plt.imshow(img1)
plt.axis("off")
# Out:
# (-0.5, 1919.5, 1079.5, -0.5)

# %%
img2=cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/test1.png",cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.axis("off")
plt.show()

# %%
#subtract img1 and img2
img1 = cv2.resize(img1, (250, 250))#Resize images to a common size
img2 = cv2.resize(img2, (250, 250))
img3=cv2.subtract(img2,img1,cv2.COLOR_BGR2RGB)
plt.title("Subtraction")
plt.imshow(img3)
plt.axis("off")
plt.show()

# %%
img1 = cv2.resize(img1, (250, 250))#Resize images to a common size
img2 = cv2.resize(img2, (250, 250))
img3=cv2.subtract(img1,img2,cv2.COLOR_BGR2RGB)
plt.title("Subtraction")
plt.imshow(img3)
plt.axis("off")
plt.show()

# %%
images=cv2.imread('/content/drive/MyDrive/images-20250302T053354Z-001/images/purple.jpg')
mean_kernel17=np.ones((1999,1999),dtype=np.float32)*(1/49)
mean_filter7=cv2.filter2D(images,-1,mean_kernel17)
plt.imshow(cv2.cvtColor(images, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 251.5, 199.5, -0.5)

# %%
img1=cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/test.png",cv2.COLOR_BGR2RGB)
mean_kernel17=np.ones((1999,1999),dtype=np.float32)*(1/49)
mean_filter7=cv2.filter2D(img1,-1,mean_kernel17)
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# (-0.5, 1919.5, 1079.5, -0.5)

# %%
img2=cv2.imread("/content/drive/MyDrive/images-20250302T053354Z-001/images/test1.png",cv2.COLOR_BGR2RGB)
mean_kernel17=np.ones((1999,1999),dtype=np.float32)*(1/49)
mean_filter7=cv2.filter2D(img2,-1,mean_kernel17)
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# (-0.5, 1919.5, 1079.5, -0.5)

# %%
img3=cv2.subtract(img2,img1,cv2.COLOR_BGR2RGB)
plt.title("Subtraction")
plt.imshow(img3)
plt.axis("off")
plt.show()

# %%
img3=cv2.subtract(img1,img2,cv2.COLOR_BGR2RGB)
plt.title("Subtraction")
plt.imshow(img3)
plt.axis("off")
plt.show()
